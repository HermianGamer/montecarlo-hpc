# %% [markdown]
# # Simulación de Montecarlo — Avance Parcial
# **Curso:** Computación de Alto Desempeño y Cloud Computing 2026-I
# **Fuente del código:** elaboración propia / [indicar si usan código externo]

# %% [markdown]
# ## 1. Carga del Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar dataset
df = pd.read_csv('../data/contaminantes_lima.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## 2. Exploración Inicial

# %%
df.info()
df.describe()

# %% [markdown]
# ## 3. Limpieza de Datos

# %%
# TODO: limpieza, valores nulos, outliers

# %% [markdown]
# ## 4. Visualizaciones Exploratorias

# %%
# TODO: histogramas, series temporales

# %% [markdown]
# ## 5. Prototipo de Simulación Montecarlo

# %%
# TODO: simulación inicial
